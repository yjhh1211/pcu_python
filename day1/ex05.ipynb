# %%
import pandas as pd

# %%
not_exercise=pd.read_excel("./data/reason.xls")

# %%
not_exercise.head()
# Out:
#      기간  대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2019  서울시  서울시               46.8               5.0               4.3
# 1  2019   성별   남자               52.4               4.4               4.9
# 2  2019   성별   여자               42.5               5.6               3.9
# 3  2019  연령별  10대               55.3               4.8               3.9
# 4  2019  연령별  20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
not_exercise.drop(columns='기간', inplace=True)
not_exercise.head()
# Out:
#    대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 0  서울시  서울시               46.8               5.0               4.3      37.3
# 1   성별   남자               52.4               4.4               4.9      32.4
# 2   성별   여자               42.5               5.6               3.9      41.0
# 3  연령별  10대               55.3               4.8               3.9      32.6
# 4  연령별  20대               46.0               4.2               4.5      38.8
#
#    운동을 할 충분한 비용이 없어서   기타
# 0                5.2  1.4
# 1                4.9  1.1
# 2                5.4  1.7
# 3                3.5    -
# 4                6.4  0.1

# %%
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시           서울시               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     연령별           20대               46.0               4.2
# 5     연령별           30대               59.9               5.2
# 6     연령별           40대               54.1               3.9
# 7     연령별           50대               46.1               6.2
# 8     연령별        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    학력별         고졸 이하               44.3               5.3
# 11    학력별         대졸 이하               53.1               4.7
# 12    학력별        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# 14    소득별  100-200만원 미만               29.6               5.6
# 15    소득별  200-300만원 미만               42.8               7.3
# 16    소득별  300-400만원 미만               50.6               4.3
# 17    소득별  400-500만원 미만               48.0               4.6
# 18    소득별      500만원 이상               52.8               4.3
# 19  혼인상태별            기혼               48.7               4.5
# 20  혼인상태별            미혼               50.2               4.9
# 21  혼인상태별      이혼/사별/기타               31.5               7.2
# 22  지역대분류           도심권               53.8               3.8
# 23  지역대분류           동북권               44.5               3.5
# 24  지역대분류           서북권               50.7               6.6
# 25  지역대분류           서남권               47.1               6.7
# 26  지역대분류           동남권               46.3               4.7
# 27    종로구           종로구               62.2               0.4
# 28     중구            중구               50.3               3.0
# 29    용산구           용산구               48.9               7.5
# 30    성동구           성동구               46.5               4.3
# 31    광진구           광진구               42.0               5.7
# 32   동대문구          동대문구               44.5               4.5
# 33    중랑구           중랑구               46.7               2.2
# 34    성북구           성북구               33.3               3.4
# 35    강북구           강북구               21.3               5.3
# 36    도봉구           도봉구               52.0               3.2
# 37    노원구           노원구               56.3               1.6
# 38    은평구           은평구               42.7               8.8
# 39   서대문구          서대문구               69.8               0.8
# 40    마포구           마포구               46.6               8.1
# 41    양천구           양천구               66.2               5.7
# 42    강서구           강서구               38.5               3.8
# 43    구로구           구로구               45.3               5.7
# 44    금천구           금천구               53.6               2.4
# 45   영등포구          영등포구               50.2               6.7
# 46    동작구           동작구               39.1              13.9
# 47    관악구           관악구               44.4               8.8
# 48    서초구           서초구               49.9               4.3
# 49    강남구           강남구               40.7               4.2
# 50    송파구           송파구               47.6               5.0
# 51    강동구           강동구               47.0               5.2
#
#     운동을 할 만한 장소가 없어서  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0                4.3      37.3                5.2   1.4
# 1                4.9      32.4                4.9   1.1
# 2                3.9      41.0                5.4   1.7
# 3                3.9      32.6                3.5     -
# 4                4.5      38.8                6.4   0.1
# 5                2.9      27.3                4.5   0.2
# 6                2.9      35.5                3.3   0.4
# 7                4.5      36.8                5.6   0.8
# 8                6.6      48.7                6.6   5.6
# 9                4.8      48.6                7.3   8.5
# 10               5.6      38.6                5.5   0.7
# 11               3.3      34.0                4.6   0.3
# 12               5.6      29.0                0.9   0.3
# 13               9.9      50.7                9.4  10.9
# 14               6.0      49.1                7.4   2.3
# 15               3.9      39.5                5.1   1.4
# 16               4.2      35.5                4.8   0.7
# 17               3.3      38.7                5.3   0.2
# 18               4.0      33.4                4.5     1
# 19               4.1      37.3                4.6   0.7
# 20               4.0      35.1                5.6   0.2
# 21               5.7      42.4                6.4   6.9
# 22               7.2      28.3                4.0   2.9
# 23               4.1      40.6                5.5   1.8
# 24               5.1      31.4                5.3   0.9
# 25               4.7      35.9                4.8   0.8
# 26               3.1      38.9                5.4   1.5
# 27               9.4      25.9                2.1     -
# 28               7.7      25.7                7.6   5.7
# 29               4.9      32.6                2.7   3.4
# 30               5.7      34.2                8.7   0.6
# 31               3.0      43.5                5.8     -
# 32               2.7      41.9                6.2   0.1
# 33               6.8      32.8               10.9   0.5
# 34               2.6      58.0                2.0   0.7
# 35               3.4      68.1                1.9     -
# 36               6.2      30.8                7.6   0.3
# 37               2.7      30.1                1.9   7.4
# 38               7.3      34.3                6.4   0.5
# 39               1.2      21.9                5.3     1
# 40               4.7      35.8                3.2   1.5
# 41               5.9      17.9                4.1   0.1
# 42               1.9      50.5                4.3     1
# 43               5.8      39.0                2.9   1.3
# 44               2.3      37.6                2.3   1.7
# 45               3.8      33.9                5.4     -
# 46               8.4      31.1                7.6     -
# 47               5.5      34.2                6.1     1
# 48               4.1      36.6                3.3   1.8
# 49               2.0      46.4                5.2   1.6
# 50               2.3      39.4                4.8     1
# 51               4.8      32.4                8.4   2.3

# %%
not_exercise.drop(index=51, inplace=True)
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시           서울시               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     연령별           20대               46.0               4.2
# 5     연령별           30대               59.9               5.2
# 6     연령별           40대               54.1               3.9
# 7     연령별           50대               46.1               6.2
# 8     연령별        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    학력별         고졸 이하               44.3               5.3
# 11    학력별         대졸 이하               53.1               4.7
# 12    학력별        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# 14    소득별  100-200만원 미만               29.6               5.6
# 15    소득별  200-300만원 미만               42.8               7.3
# 16    소득별  300-400만원 미만               50.6               4.3
# 17    소득별  400-500만원 미만               48.0               4.6
# 18    소득별      500만원 이상               52.8               4.3
# 19  혼인상태별            기혼               48.7               4.5
# 20  혼인상태별            미혼               50.2               4.9
# 21  혼인상태별      이혼/사별/기타               31.5               7.2
# 22  지역대분류           도심권               53.8               3.8
# 23  지역대분류           동북권               44.5               3.5
# 24  지역대분류           서북권               50.7               6.6
# 25  지역대분류           서남권               47.1               6.7
# 26  지역대분류           동남권               46.3               4.7
# 27    종로구           종로구               62.2               0.4
# 28     중구            중구               50.3               3.0
# 29    용산구           용산구               48.9               7.5
# 30    성동구           성동구               46.5               4.3
# 31    광진구           광진구               42.0               5.7
# 32   동대문구          동대문구               44.5               4.5
# 33    중랑구           중랑구               46.7               2.2
# 34    성북구           성북구               33.3               3.4
# 35    강북구           강북구               21.3               5.3
# 36    도봉구           도봉구               52.0               3.2
# 37    노원구           노원구               56.3               1.6
# 38    은평구           은평구               42.7               8.8
# 39   서대문구          서대문구               69.8               0.8
# 40    마포구           마포구               46.6               8.1
# 41    양천구           양천구               66.2               5.7
# 42    강서구           강서구               38.5               3.8
# 43    구로구           구로구               45.3               5.7
# 44    금천구           금천구               53.6               2.4
# 45   영등포구          영등포구               50.2               6.7
# 46    동작구           동작구               39.1              13.9
# 47    관악구           관악구               44.4               8.8
# 48    서초구           서초구               49.9               4.3
# 49    강남구           강남구               40.7               4.2
# 50    송파구           송파구               47.6               5.0
#
#     운동을 할 만한 장소가 없어서  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0                4.3      37.3                5.2   1.4
# 1                4.9      32.4                4.9   1.1
# 2                3.9      41.0                5.4   1.7
# 3                3.9      32.6                3.5     -
# 4                4.5      38.8                6.4   0.1
# 5                2.9      27.3                4.5   0.2
# 6                2.9      35.5                3.3   0.4
# 7                4.5      36.8                5.6   0.8
# 8                6.6      48.7                6.6   5.6
# 9                4.8      48.6                7.3   8.5
# 10               5.6      38.6                5.5   0.7
# 11               3.3      34.0                4.6   0.3
# 12               5.6      29.0                0.9   0.3
# 13               9.9      50.7                9.4  10.9
# 14               6.0      49.1                7.4   2.3
# 15               3.9      39.5                5.1   1.4
# 16               4.2      35.5                4.8   0.7
# 17               3.3      38.7                5.3   0.2
# 18               4.0      33.4                4.5     1
# 19               4.1      37.3                4.6   0.7
# 20               4.0      35.1                5.6   0.2
# 21               5.7      42.4                6.4   6.9
# 22               7.2      28.3                4.0   2.9
# 23               4.1      40.6                5.5   1.8
# 24               5.1      31.4                5.3   0.9
# 25               4.7      35.9                4.8   0.8
# 26               3.1      38.9                5.4   1.5
# 27               9.4      25.9                2.1     -
# 28               7.7      25.7                7.6   5.7
# 29               4.9      32.6                2.7   3.4
# 30               5.7      34.2                8.7   0.6
# 31               3.0      43.5                5.8     -
# 32               2.7      41.9                6.2   0.1
# 33               6.8      32.8               10.9   0.5
# 34               2.6      58.0                2.0   0.7
# 35               3.4      68.1                1.9     -
# 36               6.2      30.8                7.6   0.3
# 37               2.7      30.1                1.9   7.4
# 38               7.3      34.3                6.4   0.5
# 39               1.2      21.9                5.3     1
# 40               4.7      35.8                3.2   1.5
# 41               5.9      17.9                4.1   0.1
# 42               1.9      50.5                4.3     1
# 43               5.8      39.0                2.9   1.3
# 44               2.3      37.6                2.3   1.7
# 45               3.8      33.9                5.4     -
# 46               8.4      31.1                7.6     -
# 47               5.5      34.2                6.1     1
# 48               4.1      36.6                3.3   1.8
# 49               2.0      46.4                5.2   1.6
# 50               2.3      39.4                4.8     1

# %%
not_ex_sex=not_exercise[not_exercise['대분류']=='성별'].copy()
not_ex_sex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  성별  남자               52.4               4.4               4.9      32.4
# 2  성별  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
not_ex_sex.set_index('분류', inplace=True)

# %%
not_ex_sex
# Out:
#    대분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 남자  성별               52.4               4.4               4.9      32.4
# 여자  성별               42.5               5.6               3.9      41.0
#
#     운동을 할 충분한 비용이 없어서   기타
# 분류
# 남자                4.9  1.1
# 여자                5.4  1.7

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

f_path="C:\Windows\Fonts/나눔고딕.ttf"

font_name=font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
fig, ax=plt.subplots(1,2, figsize=(16,8))

not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02], ax=ax[0], autopct="%1.lf%%")
ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')

not_ex_sex['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0,0.02], ax=ax[1], autopct="%1.lf%%")
ax[1].set_title('함께 운동을 할 사람이 없어서')
ax[1].set_ylabel('')

plt.show()

# %%
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시           서울시               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     연령별           20대               46.0               4.2
# 5     연령별           30대               59.9               5.2
# 6     연령별           40대               54.1               3.9
# 7     연령별           50대               46.1               6.2
# 8     연령별        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    학력별         고졸 이하               44.3               5.3
# 11    학력별         대졸 이하               53.1               4.7
# 12    학력별        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# 14    소득별  100-200만원 미만               29.6               5.6
# 15    소득별  200-300만원 미만               42.8               7.3
# 16    소득별  300-400만원 미만               50.6               4.3
# 17    소득별  400-500만원 미만               48.0               4.6
# 18    소득별      500만원 이상               52.8               4.3
# 19  혼인상태별            기혼               48.7               4.5
# 20  혼인상태별            미혼               50.2               4.9
# 21  혼인상태별      이혼/사별/기타               31.5               7.2
# 22  지역대분류           도심권               53.8               3.8
# 23  지역대분류           동북권               44.5               3.5
# 24  지역대분류           서북권               50.7               6.6
# 25  지역대분류           서남권               47.1               6.7
# 26  지역대분류           동남권               46.3               4.7
# 27    종로구           종로구               62.2               0.4
# 28     중구            중구               50.3               3.0
# 29    용산구           용산구               48.9               7.5
# 30    성동구           성동구               46.5               4.3
# 31    광진구           광진구               42.0               5.7
# 32   동대문구          동대문구               44.5               4.5
# 33    중랑구           중랑구               46.7               2.2
# 34    성북구           성북구               33.3               3.4
# 35    강북구           강북구               21.3               5.3
# 36    도봉구           도봉구               52.0               3.2
# 37    노원구           노원구               56.3               1.6
# 38    은평구           은평구               42.7               8.8
# 39   서대문구          서대문구               69.8               0.8
# 40    마포구           마포구               46.6               8.1
# 41    양천구           양천구               66.2               5.7
# 42    강서구           강서구               38.5               3.8
# 43    구로구           구로구               45.3               5.7
# 44    금천구           금천구               53.6               2.4
# 45   영등포구          영등포구               50.2               6.7
# 46    동작구           동작구               39.1              13.9
# 47    관악구           관악구               44.4               8.8
# 48    서초구           서초구               49.9               4.3
# 49    강남구           강남구               40.7               4.2
# 50    송파구           송파구               47.6               5.0
#
#     운동을 할 만한 장소가 없어서  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0                4.3      37.3                5.2   1.4
# 1                4.9      32.4                4.9   1.1
# 2                3.9      41.0                5.4   1.7
# 3                3.9      32.6                3.5     -
# 4                4.5      38.8                6.4   0.1
# 5                2.9      27.3                4.5   0.2
# 6                2.9      35.5                3.3   0.4
# 7                4.5      36.8                5.6   0.8
# 8                6.6      48.7                6.6   5.6
# 9                4.8      48.6                7.3   8.5
# 10               5.6      38.6                5.5   0.7
# 11               3.3      34.0                4.6   0.3
# 12               5.6      29.0                0.9   0.3
# 13               9.9      50.7                9.4  10.9
# 14               6.0      49.1                7.4   2.3
# 15               3.9      39.5                5.1   1.4
# 16               4.2      35.5                4.8   0.7
# 17               3.3      38.7                5.3   0.2
# 18               4.0      33.4                4.5     1
# 19               4.1      37.3                4.6   0.7
# 20               4.0      35.1                5.6   0.2
# 21               5.7      42.4                6.4   6.9
# 22               7.2      28.3                4.0   2.9
# 23               4.1      40.6                5.5   1.8
# 24               5.1      31.4                5.3   0.9
# 25               4.7      35.9                4.8   0.8
# 26               3.1      38.9                5.4   1.5
# 27               9.4      25.9                2.1     -
# 28               7.7      25.7                7.6   5.7
# 29               4.9      32.6                2.7   3.4
# 30               5.7      34.2                8.7   0.6
# 31               3.0      43.5                5.8     -
# 32               2.7      41.9                6.2   0.1
# 33               6.8      32.8               10.9   0.5
# 34               2.6      58.0                2.0   0.7
# 35               3.4      68.1                1.9     -
# 36               6.2      30.8                7.6   0.3
# 37               2.7      30.1                1.9   7.4
# 38               7.3      34.3                6.4   0.5
# 39               1.2      21.9                5.3     1
# 40               4.7      35.8                3.2   1.5
# 41               5.9      17.9                4.1   0.1
# 42               1.9      50.5                4.3     1
# 43               5.8      39.0                2.9   1.3
# 44               2.3      37.6                2.3   1.7
# 45               3.8      33.9                5.4     -
# 46               8.4      31.1                7.6     -
# 47               5.5      34.2                6.1     1
# 48               4.1      36.6                3.3   1.8
# 49               2.0      46.4                5.2   1.6
# 50               2.3      39.4                4.8     1

# %%
not_ex_age=not_exercise[not_exercise['대분류']=='연령대'].copy()
not_ex_age
# Out:
# Empty DataFrame
# Columns: [대분류, 분류, 운동을 할 충분한 시간이 없어서, 함께 운동을 할 사람이 없어서, 운동을 할 만한 장소가 없어서, 운동을 싫어해서, 운동을 할 충분한 비용이 없어서, 기타]
# Index: []

# %%
not_ex_age.drop(columns='대분류', inplace=True)
not_ex_age
# Out:
# Empty DataFrame
# Columns: [분류, 운동을 할 충분한 시간이 없어서, 함께 운동을 할 사람이 없어서, 운동을 할 만한 장소가 없어서, 운동을 싫어해서, 운동을 할 충분한 비용이 없어서, 기타]
# Index: []

# %%
not_ex_age.set_index('분류', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-b518e3606df8> in <module>
# ----> 1 not_ex_age.set_index('분류', inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['분류'] are in the columns"

# %%
not_ex_age
# Out:
# Empty DataFrame
# Columns: [운동을 할 충분한 시간이 없어서, 함께 운동을 할 사람이 없어서, 운동을 할 만한 장소가 없어서, 운동을 싫어해서, 운동을 할 충분한 비용이 없어서, 기타]
# Index: []

# %%
fig, ax=plt.subplots(1,3, figsize=(16,8))

not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02], ax=ax[0], autopct="%1.lf%%")
ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')

not_ex_sex['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0,0.02], ax=ax[1], autopct="%1.lf%%")
ax[1].set_title('함께 운동을 할 사람이 없어서')
ax[1].set_ylabel('')

not_ex_sex['운동을 할 만한 장소가 없어서'].plot.pie(explode=[0,0.02], ax=ax[2], autopct="%1.lf%%")
ax[2].set_title('운동을 할 만한 장소가 없어서')
ax[2].set_ylabel('')

plt.show()
